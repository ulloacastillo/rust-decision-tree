# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('iris.csv', header=None)
X = data.iloc[: , :4]
y = pd.Series(map(str, data.iloc[: , 4]))

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier(criterion='gini')

# %%
import os

os.system('cargo rustc --release -- -C opt-level=3 -C target-cpu=native -C debuginfo=0')
# Out:
# warning: unused import: `csv::Error`
#  --> src/main.rs:4:5
#   |
# 4 | use csv::Error;
#   |     ^^^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `Duration`
#  --> src/main.rs:5:17
#   |
# 5 | use std::time::{Duration, Instant};
#   |                 ^^^^^^^^
#
# warning: unused import: `std::fs::File`
#  --> src/dtree.rs:1:5
#   |
# 1 | use std::fs::File;
#   |     ^^^^^^^^^^^^^
#
# warning: unused import: `rand::prelude::*`
#  --> src/dtree.rs:3:5
#   |
# 3 | use rand::prelude::*;
#   |     ^^^^^^^^^^^^^^^^
#
# warning: unused import: `csv::Error`
#  --> src/dtree.rs:4:5
#   |
# 4 | use csv::Error;
#   |     ^^^^^^^^^^
#
# warning: unused import: `Duration`
#  --> src/dtree.rs:6:17
#   |
# 6 | use std::time::{Duration, Instant};
#   |                 ^^^^^^^^
#
# warning: unused import: `array_tool::vec::Uniq`
#  --> src/dtree.rs:7:5
#   |
# 7 | use array_tool::vec::Uniq;
#   |     ^^^^^^^^^^^^^^^^^^^^^
#
# warning: unused import: `std::fs::File`
#  --> src/dtree/utils.rs:1:5
#   |
# 1 | use std::fs::File;
#   |     ^^^^^^^^^^^^^
#
# warning: unused import: `std::io::prelude::*`
#  --> src/dtree/utils.rs:2:5
#   |
# 2 | use std::io::prelude::*;
#   |     ^^^^^^^^^^^^^^^^^^^
#
# warning: unused import: `rand::prelude::*`
#  --> src/dtree/utils.rs:3:5
#   |
# 3 | use rand::prelude::*;
#   |     ^^^^^^^^^^^^^^^^
#
# warning: unused import: `csv::Error`
#  --> src/dtree/utils.rs:4:5
#   |
# 4 | use csv::Error;
#   |     ^^^^^^^^^^
#
# warning: unnecessary parentheses around block return value
#    --> src/dtree.rs:214:9
#     |
# 214 |         (1.0 - gini)
#     |         ^          ^
#     |
#     = note: `#[warn(unused_parens)]` on by default
# help: remove these parentheses
#     |
# 214 -         (1.0 - gini)
# 214 +         1.0 - gini
#     |
#
# warning: unused import: `std::fs::File`
#  --> src/utils.rs:1:5
#   |
# 1 | use std::fs::File;
#   |     ^^^^^^^^^^^^^
#
# warning: unused import: `std::io::prelude::*`
#  --> src/utils.rs:2:5
#   |
# 2 | use std::io::prelude::*;
#   |     ^^^^^^^^^^^^^^^^^^^
#
# warning: unused import: `rand::prelude::*`
#  --> src/utils.rs:3:5
#   |
# 3 | use rand::prelude::*;
#   |     ^^^^^^^^^^^^^^^^
#
# warning: unused import: `csv::Error`
#  --> src/utils.rs:4:5
#   |
# 4 | use csv::Error;
#   |     ^^^^^^^^^^
#
# warning: unnecessary parentheses around `while` condition
#   --> src/random_forest.rs:20:15
#    |
# 20 |         while (ft_ixs.contains(&rnd_ft_idx)) {
#    |               ^                            ^
#    |
# help: remove these parentheses
#    |
# 20 -         while (ft_ixs.contains(&rnd_ft_idx)) {
# 20 +         while ft_ixs.contains(&rnd_ft_idx) {
#    |
#
# warning: unused import: `std::io::prelude`
#  --> src/dtree.rs:2:5
#   |
# 2 | use std::io::prelude::*;
#   |     ^^^^^^^^^^^^^^^^
#
# warning: unused import: `rand::prelude`
#  --> src/main.rs:3:5
#   |
# 3 | use rand::prelude::*;
#   |     ^^^^^^^^^^^^^
#
# warning: unused variable: `depth`
#   --> src/dtree.rs:79:17
#    |
# 79 |             let depth = self.max_depth as f32;
#    |                 ^^^^^ help: if this is intentional, prefix it with an underscore: `_depth`
#    |
#    = note: `#[warn(unused_variables)]` on by default
#
# warning: variable `c` is assigned to, but never used
#    --> src/dtree.rs:143:21
#     |
# 143 |             let mut c = 0;
#     |                     ^
#     |
#     = note: consider using `_c` instead
#
# warning: unused variable: `num_samples`
#    --> src/dtree.rs:117:65
#     |
# 117 |     pub fn get_best_split(&mut self, X: &Matrix, Y:  &Vec<i32>, num_samples: usize, num_features: usize) -> BestSplitStruct{
#     |                                                                 ^^^^^^^^^^^ help: if this is intentional, prefix it with an underscore: `_num_samples`
#
# warning: unused variable: `now`
#    --> src/dtree.rs:192:13
#     |
# 192 |         let now = Instant::now();
#     |             ^^^ help: if this is intentional, prefix it with an underscore: `_now`
#
# warning: unused variable: `now2`
#    --> src/dtree.rs:196:13
#     |
# 196 |         let now2 = Instant::now();
#     |             ^^^^ help: if this is intentional, prefix it with an underscore: `_now2`
#
# warning: unused variable: `now`
#    --> src/dtree.rs:199:13
#     |
# 199 |         let now = Instant::now();
#     |             ^^^ help: if this is intentional, prefix it with an underscore: `_now`
#
# warning: unused variable: `now2`
#    --> src/dtree.rs:212:13
#     |
# 212 |         let now2 = Instant::now();
#     |             ^^^^ help: if this is intentional, prefix it with an underscore: `_now2`
#
# warning: unused variable: `i`
#   --> src/random_forest.rs:18:9
#    |
# 18 |     for i in 0..n_features {
#    |         ^ help: if this is intentional, prefix it with an underscore: `_i`
#
# warning: unused variable: `i`
#   --> src/random_forest.rs:29:9
#    |
# 29 |     for i in 0..n_samples {
#    |         ^ help: if this is intentional, prefix it with an underscore: `_i`
#
# warning: unused variable: `rng`
#    --> src/random_forest.rs:122:17
#     |
# 122 |         let mut rng = rand::rngs::StdRng::seed_from_u64(self.seed);
#     |                 ^^^ help: if this is intentional, prefix it with an underscore: `_rng`
#
# warning: unused variable: `x_array`
#   --> src/main.rs:62:13
#    |
# 62 |     let mut x_array = [vec![5.1,3.5,1.4,0.2,1.],
#    |             ^^^^^^^ help: if this is intentional, prefix it with an underscore: `_x_array`
#
# warning: unused variable: `y_array`
#   --> src/main.rs:70:13
#    |
# 70 |     let mut y_array = [1, 1, 2, 2, 3, 3, 1];
#    |             ^^^^^^^ help: if this is intentional, prefix it with an underscore: `_y_array`
#
# warning: variable does not need to be mutable
#    --> src/dtree.rs:261:17
#     |
# 261 |             let mut v = &(X.data[(i*n_cols)..(i*n_cols + n_cols)]);
#     |                 ----^
#     |                 |
#     |                 help: remove this `mut`
#     |
#     = note: `#[warn(unused_mut)]` on by default
#
# warning: variable does not need to be mutable
#    --> src/dtree.rs:276:13
#     |
# 276 |         let mut dataset_left: Matrix = Matrix { data: vec_left, row: row_left, col: n_cols};
#     |             ----^^^^^^^^^^^^
#     |             |
#     |             help: remove this `mut`
#
# warning: variable does not need to be mutable
#    --> src/dtree.rs:277:13
#     |
# 277 |         let mut dataset_right: Matrix = Matrix { data: vec_right, row: row_right, col: n_cols};
#     |             ----^^^^^^^^^^^^^
#     |             |
#     |             help: remove this `mut`
#
# warning: variable does not need to be mutable
#    --> src/random_forest.rs:122:13
#     |
# 122 |         let mut rng = rand::rngs::StdRng::seed_from_u64(self.seed);
#     |             ----^^^
#     |             |
#     |             help: remove this `mut`
#
# warning: variable does not need to be mutable
#   --> src/main.rs:62:9
#    |
# 62 |     let mut x_array = [vec![5.1,3.5,1.4,0.2,1.],
#    |         ----^^^^^^^
#    |         |
#    |         help: remove this `mut`
#
# warning: variable does not need to be mutable
#   --> src/main.rs:70:9
#    |
# 70 |     let mut y_array = [1, 1, 2, 2, 3, 3, 1];
#    |         ----^^^^^^^
#    |         |
#    |         help: remove this `mut`
#
# warning: function `print_type_of` is never used
#   --> src/main.rs:12:4
#    |
# 12 | fn print_type_of<T>(_: &T) {
#    |    ^^^^^^^^^^^^^
#    |
#    = note: `#[warn(dead_code)]` on by default
#
# warning: associated function `new` is never used
#   --> src/dtree.rs:40:12
#    |
# 40 |     pub fn new(fi: usize, th: f32, v: i32) -> Self {
#    |            ^^^
#
# warning: associated function `make_prediction` is never used
#    --> src/dtree.rs:327:12
#     |
# 327 |     pub fn make_prediction(&self, X: &Vec<f32>, tree: &Option<Box<Node>>) -> i32{
#     |            ^^^^^^^^^^^^^^^
#
# warning: associated function `predict` is never used
#    --> src/dtree.rs:349:12
#     |
# 349 |     pub fn predict(&self, X: &Vec<Vec<f32>>) -> Vec<i32> {
#     |            ^^^^^^^
#
# warning: function `set_panic_hook` is never used
#  --> src/dtree/utils.rs:8:8
#   |
# 8 | pub fn set_panic_hook() {
#   |        ^^^^^^^^^^^^^^
#
# warning: function `count_value_occurrences` is never used
#   --> src/dtree/utils.rs:89:8
#    |
# 89 | pub fn count_value_occurrences<T: Eq>(values: &Vec<T>, value: &T) -> usize {
#    |        ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: function `find_unique_values` is never used
#    --> src/dtree/utils.rs:112:8
#     |
# 112 | pub fn find_unique_values<T: Eq + std::hash::Hash>(values: &Vec<T>) -> Vec<&T> {
#     |        ^^^^^^^^^^^^^^^^^^
#
# warning: function `set_panic_hook` is never used
#  --> src/utils.rs:8:8
#   |
# 8 | pub fn set_panic_hook() {
#   |        ^^^^^^^^^^^^^^
#
# warning: function `count_vals` is never used
#   --> src/utils.rs:78:8
#    |
# 78 | pub fn count_vals(arr: &Vec<i32>, label: &i32) -> usize {
#    |        ^^^^^^^^^^
#
# warning: function `count_value_occurrences` is never used
#   --> src/utils.rs:90:8
#    |
# 90 | pub fn count_value_occurrences<T: Eq>(values: &Vec<T>, value: &T) -> usize {
#    |        ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: function `unique_vals` is never used
#   --> src/utils.rs:96:8
#    |
# 96 | pub fn unique_vals(arr: &Vec<i32>) -> Vec<i32> {
#    |        ^^^^^^^^^^^
#
# warning: function `find_unique_values` is never used
#    --> src/utils.rs:114:8
#     |
# 114 | pub fn find_unique_values<T: Eq + std::hash::Hash>(values: &Vec<T>) -> Vec<&T> {
#     |        ^^^^^^^^^^^^^^^^^^
#
# warning: function `unique_vals_f32` is never used
#    --> src/utils.rs:128:8
#     |
# 128 | pub fn unique_vals_f32(arr: &Vec<f32>) -> Vec<f32> {
#     |        ^^^^^^^^^^^^^^^
#
# warning: function `get_column` is never used
#    --> src/utils.rs:145:8
#     |
# 145 | pub fn get_column(matrix: &Matrix, ncol: usize) -> Vec<f32>{
#     |        ^^^^^^^^^^
#
# warning: function `bootstrap_random_forest` is never used
#  --> src/random_forest.rs:8:8
#   |
# 8 | pub fn bootstrap_random_forest(X: &Vec<Vec<f32>>, Y: &Vec<i32>, n_features: usize, rng: &mut rand::rngs::StdRng) -> (Vec<Ve...
#   |        ^^^^^^^^^^^^^^^^^^^^^^^
#
# warning: function `swap_matrix_axes` is never used
#   --> src/random_forest.rs:43:8
#    |
# 43 | pub fn swap_matrix_axes(matrix: &Vec<Vec<i32>>) -> Vec<Vec<i32>>{
#    |        ^^^^^^^^^^^^^^^^
#
# warning: function `count_val` is never used
#   --> src/random_forest.rs:61:8
#    |
# 61 | pub fn count_val(el: i32, Y: &Vec<i32>) -> usize{
#    |        ^^^^^^^^^
#
# warning: function `get_most_common` is never used
#   --> src/random_forest.rs:70:8
#    |
# 70 | pub fn get_most_common(Y: &Vec<i32>) -> i32 {
#    |        ^^^^^^^^^^^^^^^
#
# warning: function `accuracy` is never used
#   --> src/random_forest.rs:84:8
#    |
# 84 | pub fn accuracy(y: &Vec<String>, y_hat: &Vec<String>) -> f32{
#    |        ^^^^^^^^
#
# warning: associated function `new` is never used
#    --> src/random_forest.rs:106:12
#     |
# 106 |     pub fn new(n_trees: usize, min_samples_split: usize, max_depth: usize, n_feats: usize, seed: u64) -> Self {
#     |            ^^^
#
# warning: associated function `fit` is never used
#    --> src/random_forest.rs:118:12
#     |
# 118 |     pub fn fit(&mut self, X: &Matrix, Y: &Vec<i32>) {
#     |            ^^^
#
# warning: associated function `predict` is never used
#    --> src/random_forest.rs:140:12
#     |
# 140 |     pub fn predict(&mut self, X: &Vec<Vec<f32>>) -> Vec<i32> {
#     |            ^^^^^^^
#
# warning: unused borrow that must be used
#   --> src/main.rs:46:9
#    |
# 46 |         &y.push(b.parse::<i32>().unwrap());
#    |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ the borrow produces a value
#    |
#    = note: `#[warn(unused_must_use)]` on by default
# help: use `let _ = ...` to ignore the resulting value
#    |
# 46 |         let _ = &y.push(b.parse::<i32>().unwrap());
#    |         +++++++
#
# warning: unused borrow that must be used
#   --> src/main.rs:47:9
#    |
# 47 |         &x.append(&mut aux);
#    |         ^^^^^^^^^^^^^^^^^^^ the borrow produces a value
#    |
# help: use `let _ = ...` to ignore the resulting value
#    |
# 47 |         let _ = &x.append(&mut aux);
#    |         +++++++
#
# warning: variable `X` should have a snake case name
#   --> src/dtree.rs:70:34
#    |
# 70 |     pub fn build_tree(&mut self, X: &Matrix, Y: &Vec<i32>, curr_depth: usize) -> Option<Box<Node>>{
#    |                                  ^ help: convert the identifier to snake case (notice the capitalization): `x`
#    |
#    = note: `#[warn(non_snake_case)]` on by default
#
# warning: variable `Y` should have a snake case name
#   --> src/dtree.rs:70:46
#    |
# 70 |     pub fn build_tree(&mut self, X: &Matrix, Y: &Vec<i32>, curr_depth: usize) -> Option<Box<Node>>{
#    |                                              ^ help: convert the identifier to snake case (notice the capitalization): `y`
#
# warning: variable `X` should have a snake case name
#    --> src/dtree.rs:117:38
#     |
# 117 |     pub fn get_best_split(&mut self, X: &Matrix, Y:  &Vec<i32>, num_samples: usize, num_features: usize) -> BestSplitStruct{
#     |                                      ^ help: convert the identifier to snake case (notice the capitalization): `x`
#
# warning: variable `Y` should have a snake case name
#    --> src/dtree.rs:117:50
#     |
# 117 |     pub fn get_best_split(&mut self, X: &Matrix, Y:  &Vec<i32>, num_samples: usize, num_features: usize) -> BestSplitStruct{
#     |                                                  ^ help: convert the identifier to snake case (notice the capitalization): `y`
#
# warning: variable `Y` should have a snake case name
#    --> src/dtree.rs:191:34
#     |
# 191 |     pub fn gini_index(&mut self, Y: &Vec<i32>) -> f32 {
#     |                                  ^ help: convert the identifier to snake case (notice the capitalization): `y`
#
# warning: variable `X` should have a snake case name
#    --> src/dtree.rs:245:29
#     |
# 245 |     pub fn split(&mut self, X: &Matrix, Y: &Vec<i32>, feature_index: usize, threshold: f32) -> (Matrix, Matrix, Vec<i32>,...
#     |                             ^ help: convert the identifier to snake case (notice the capitalization): `x`
#
# warning: variable `Y` should have a snake case name
#    --> src/dtree.rs:245:41
#     |
# 245 |     pub fn split(&mut self, X: &Matrix, Y: &Vec<i32>, feature_index: usize, threshold: f32) -> (Matrix, Matrix, Vec<i32>,...
#     |                                         ^ help: convert the identifier to snake case (notice the capitalization): `y`
#
# warning: variable `Y` should have a snake case name
#    --> src/dtree.rs:298:44
#     |
# 298 |     pub fn calculate_leaf_value(&mut self, Y: &Vec<i32> ) -> i32{
#     |                                            ^ help: convert the identifier to snake case (notice the capitalization): `y`
#
# warning: variable `X` should have a snake case name
#    --> src/dtree.rs:323:27
#     |
# 323 |     pub fn fit(&mut self, X: &Matrix, Y: &Vec<i32>) {
#     |                           ^ help: convert the identifier to snake case (notice the capitalization): `x`
#
# warning: variable `Y` should have a snake case name
#    --> src/dtree.rs:323:39
#     |
# 323 |     pub fn fit(&mut self, X: &Matrix, Y: &Vec<i32>) {
#     |                                       ^ help: convert the identifier to snake case (notice the capitalization): `y`
#
# warning: variable `X` should have a snake case name
#    --> src/dtree.rs:327:35
#     |
# 327 |     pub fn make_prediction(&self, X: &Vec<f32>, tree: &Option<Box<Node>>) -> i32{
#     |                                   ^ help: convert the identifier to snake case (notice the capitalization): `x`
#
# warning: variable `X` should have a snake case name
#    --> src/dtree.rs:349:27
#     |
# 349 |     pub fn predict(&self, X: &Vec<Vec<f32>>) -> Vec<i32> {
#     |                           ^ help: convert the identifier to snake case (notice the capitalization): `x`
#
# warning: variable `X` should have a snake case name
#  --> src/random_forest.rs:8:32
#   |
# 8 | pub fn bootstrap_random_forest(X: &Vec<Vec<f32>>, Y: &Vec<i32>, n_features: usize, rng: &mut rand::rngs::StdRng) -> (Vec<Ve...
#   |                                ^ help: convert the identifier to snake case (notice the capitalization): `x`
#
# warning: variable `Y` should have a snake case name
#  --> src/random_forest.rs:8:51
#   |
# 8 | ...t(X: &Vec<Vec<f32>>, Y: &Vec<i32>, n_features: usize, rng: &mut rand::rngs::StdRng) -> (Vec<Vec<f32>>, Vec<i32>) {
#   |                         ^ help: convert the identifier to snake case (notice the capitalization): `y`
#
# warning: variable `X_` should have a snake case name
#   --> src/random_forest.rs:10:13
#    |
# 10 |     let mut X_: Vec<Vec<f32>> = vec![];
#    |             ^^ help: convert the identifier to snake case: `x`
#
# warning: variable `X_i` should have a snake case name
#   --> src/random_forest.rs:32:17
#    |
# 32 |         let mut X_i: Vec<f32> = vec![];
#    |                 ^^^ help: convert the identifier to snake case (notice the capitalization): `x_i`
#
# warning: variable `Y` should have a snake case name
#   --> src/random_forest.rs:61:27
#    |
# 61 | pub fn count_val(el: i32, Y: &Vec<i32>) -> usize{
#    |                           ^ help: convert the identifier to snake case (notice the capitalization): `y`
#
# warning: variable `Y` should have a snake case name
#   --> src/random_forest.rs:70:24
#    |
# 70 | pub fn get_most_common(Y: &Vec<i32>) -> i32 {
#    |                        ^ help: convert the identifier to snake case (notice the capitalization): `y`
#
# warning: variable `X` should have a snake case name
#    --> src/random_forest.rs:118:27
#     |
# 118 |     pub fn fit(&mut self, X: &Matrix, Y: &Vec<i32>) {
#     |                           ^ help: convert the identifier to snake case (notice the capitalization): `x`
#
# warning: variable `Y` should have a snake case name
#    --> src/random_forest.rs:118:39
#     |
# 118 |     pub fn fit(&mut self, X: &Matrix, Y: &Vec<i32>) {
#     |                                       ^ help: convert the identifier to snake case (notice the capitalization): `y`
#
# warning: variable `X` should have a snake case name
#    --> src/random_forest.rs:140:31
#     |
# 140 |     pub fn predict(&mut self, X: &Vec<Vec<f32>>) -> Vec<i32> {
#     |                               ^ help: convert the identifier to snake case (notice the capitalization): `x`
#
# warning: `decision-tree` (bin "decision-tree") generated 82 warnings
#     Finished release [optimized] target(s) in 0.52s
# 0

# %%
import subprocess
import statistics
import warnings

warnings.filterwarnings("ignore")

# Define a list of input values
n = 25
# Initialize an empty list to store the outputs
outputs = []


ns = range(1000, 10001, 1000)

# Loop over the input values and execute the command

for row in ns:
    inner_t = []

    for i in range(n):
        # Execute the command and capture the output
        output = subprocess.check_output(
            [f'./target/release/decision-tree {row} 4'], shell=True, text=True)

        # Append the output to the list of outputs
        
        inner_t.append(float(output.strip('ms\n')))
        # outputs.append(output)

    outputs.append(np.mean(inner_t))

    # Print the outputs

# %%
plt.plot(ns, outputs)

# %%
tree_outputs = []

# %%
import time

t = %timeit -n 1 -r 5 -o time.sleep(1)
t?
# Out:
# 1 s ± 1.37 ms per loop (mean ± std. dev. of 5 runs, 1 loop each)

# %%
np.mean(t.all_runs) / t.repeat
# Out:
# 0.20072182488162071

# %%
t.all_runs
# Out:
# [1.0010798139264807,
#  1.003504030057229,
#  1.0048965179594234,
#  1.0038189310580492,
#  1.0047463290393353]

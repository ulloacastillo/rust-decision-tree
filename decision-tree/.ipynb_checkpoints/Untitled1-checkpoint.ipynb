# %%
import numpy as np
import pandas as pd

# %%
col_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'type']
data = pd.read_csv("iris.csv",  header=None, names=col_names)
data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    type
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.4          3.7           1.5          0.2  setosa
# 8           4.8          3.4           1.6          0.2  setosa
# 9           4.8          3.0           1.4          0.1  setosa

# %%
class Node():
    def __init__(self, feature_index=None, threshold=None, left=None, right=None, info_gain=None, value=None):
        ''' constructor ''' 
        
        # for decision node
        self.feature_index = feature_index
        self.threshold = threshold
        self.left = left
        self.right = right
        self.info_gain = info_gain
        
        # for leaf node
        self.value = value

# %%
class DecisionTreeClassifier():
    def __init__(self, min_samples_split=2, max_depth=2):
        ''' constructor '''
        
        # initialize the root of the tree 
        self.root = None
        
        # stopping conditions
        self.min_samples_split = min_samples_split
        self.max_depth = max_depth
        
    def build_tree(self, dataset, curr_depth=0):
        ''' recursive function to build the tree ''' 
        
        X, Y = dataset[:,:-1], dataset[:,-1]
        num_samples, num_features = np.shape(X)
        
        # split until stopping conditions are met
        if num_samples>=self.min_samples_split and curr_depth<=self.max_depth:
            # find the best split

            best_split = self.get_best_split(dataset, num_samples, num_features)
            # check if information gain is positive
            print(best_split)
            if best_split["info_gain"]>0:

                # recur left
                left_subtree = self.build_tree(best_split["dataset_left"], curr_depth+1)
                # recur right
                right_subtree = self.build_tree(best_split["dataset_right"], curr_depth+1)
                # return decision node
                return Node(best_split["feature_index"], best_split["threshold"], 
                            left_subtree, right_subtree, best_split["info_gain"])
        
        # compute leaf node
        leaf_value = self.calculate_leaf_value(Y)
        # return leaf node
        return Node(value=leaf_value)
    
    def get_best_split(self, dataset, num_samples, num_features):
        ''' function to find the best split '''
        
        # dictionary to store the best split
        best_split = {}
        max_info_gain = -float("inf")
        
        # loop over all the features
        for feature_index in range(num_features):
            feature_values = dataset[:, feature_index]
            possible_thresholds = np.unique(feature_values)
            # loop over all the feature values present in the data
            for threshold in possible_thresholds:
                # get current split
                dataset_left, dataset_right = self.split(dataset, feature_index, threshold)
                # check if childs are not null
                if len(dataset_left)>0 and len(dataset_right)>0:
                    y, left_y, right_y = dataset[:, -1], dataset_left[:, -1], dataset_right[:, -1]
                    # compute information gain
                    curr_info_gain = self.information_gain(y, left_y, right_y, "gini")
                    # update the best split if needed
                    if curr_info_gain>max_info_gain:
                        best_split["feature_index"] = feature_index
                        best_split["threshold"] = threshold
                        best_split["dataset_left"] = dataset_left
                        best_split["dataset_right"] = dataset_right
                        best_split["info_gain"] = curr_info_gain
                        max_info_gain = curr_info_gain
                        
        # return best split
        return best_split
    
    def split(self, dataset, feature_index, threshold):
        ''' function to split the data '''
        
        dataset_left = np.array([row for row in dataset if row[feature_index]<=threshold])
        dataset_right = np.array([row for row in dataset if row[feature_index]>threshold])
        
        #print(dataset_left, dataset_right)
        
        return dataset_left, dataset_right
    
    def information_gain(self, parent, l_child, r_child, mode="entropy"):
        ''' function to compute information gain '''
        
        weight_l = len(l_child) / len(parent)
        weight_r = len(r_child) / len(parent)
        if mode=="gini":
            gain = self.gini_index(parent) - (weight_l*self.gini_index(l_child) + weight_r*self.gini_index(r_child))
        else:
            gain = self.entropy(parent) - (weight_l*self.entropy(l_child) + weight_r*self.entropy(r_child))
        return gain
    
    def entropy(self, y):
        ''' function to compute entropy '''
        
        class_labels = np.unique(y)
        entropy = 0
        for cls in class_labels:
            p_cls = len(y[y == cls]) / len(y)
            entropy += -p_cls * np.log2(p_cls)
        return entropy
    
    def gini_index(self, y):
        ''' function to compute gini index '''
        
        class_labels = np.unique(y)
        gini = 0
        for cls in class_labels:
            p_cls = len(y[y == cls]) / len(y)
            gini += p_cls**2
        return 1 - gini
        
    def calculate_leaf_value(self, Y):
        ''' function to compute leaf node '''
        
        Y = list(Y)
        return max(Y, key=Y.count)
    
    def print_tree(self, tree=None, indent=" "):
        ''' function to print the tree '''
        
        if not tree:
            tree = self.root

        if tree.value is not None:
            print(tree.value)

        else:
            print("X_"+str(tree.feature_index), "<=", tree.threshold, "?", tree.info_gain)
            print("%sleft:" % (indent), end="")
            self.print_tree(tree.left, indent + indent)
            print("%sright:" % (indent), end="")
            self.print_tree(tree.right, indent + indent)
    
    def fit(self, X, Y):
        ''' function to train the tree '''
        
        dataset = np.concatenate((X, Y), axis=1)
        
        self.root = self.build_tree(dataset)
    
    def predict(self, X):
        ''' function to predict new dataset '''
        
        preditions = [self.make_prediction(x, self.root) for x in X]
        return preditions
    
    def make_prediction(self, x, tree):
        ''' function to predict a single data point '''
        
        if tree.value!=None: return tree.value
        feature_val = x[tree.feature_index]
        if feature_val<=tree.threshold:
            return self.make_prediction(x, tree.left)
        else:
            return self.make_prediction(x, tree.right)

# %%
X = data.iloc[:, :-1].values
Y = data.iloc[:, -1].values.reshape(-1,1)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=41)

# %%
classifier = DecisionTreeClassifier(min_samples_split=3, max_depth=3)
classifier.fit(X_train,Y_train)
classifier.print_tree()
# Out:
# {'feature_index': 2, 'threshold': 1.9, 'dataset_left': array([[5.0, 3.5, 1.3, 0.3, 'setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'setosa'],
#        [5.0, 3.2, 1.2, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [5.3, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.1, 1.6, 0.2, 'setosa'],
#        [5.5, 3.5, 1.3, 0.2, 'setosa'],
#        [4.4, 3.0, 1.3, 0.2, 'setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.2, 3.4, 1.4, 0.2, 'setosa'],
#        [5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [5.2, 3.5, 1.5, 0.2, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.3, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.0, 3.5, 1.6, 0.6, 'setosa'],
#        [5.2, 4.1, 1.5, 0.1, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.1, 3.4, 1.5, 0.2, 'setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'setosa'],
#        [4.8, 3.4, 1.9, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.3, 1.4, 0.2, 'setosa'],
#        [4.9, 3.6, 1.4, 0.1, 'setosa'],
#        [5.0, 3.0, 1.6, 0.2, 'setosa'],
#        [4.6, 3.2, 1.4, 0.2, 'setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.4, 3.4, 1.5, 0.4, 'setosa'],
#        [4.7, 3.2, 1.6, 0.2, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa']], dtype=object), 'dataset_right': array([[6.7, 3.3, 5.7, 2.1, 'virginica'],
#        [6.8, 3.2, 5.9, 2.3, 'virginica'],
#        [6.0, 2.9, 4.5, 1.5, 'versicolor'],
#        [5.8, 2.7, 5.1, 1.9, 'virginica'],
#        [5.1, 2.5, 3.0, 1.1, 'versicolor'],
#        [6.4, 2.8, 5.6, 2.2, 'virginica'],
#        [6.5, 3.0, 5.2, 2.0, 'virginica'],
#        [5.6, 2.7, 4.2, 1.3, 'versicolor'],
#        [6.4, 3.1, 5.5, 1.8, 'virginica'],
#        [7.3, 2.9, 6.3, 1.8, 'virginica'],
#        [6.0, 2.2, 5.0, 1.5, 'virginica'],
#        [7.7, 2.8, 6.7, 2.0, 'virginica'],
#        [6.2, 3.4, 5.4, 2.3, 'virginica'],
#        [7.7, 2.6, 6.9, 2.3, 'virginica'],
#        [5.4, 3.0, 4.5, 1.5, 'versicolor'],
#        [6.4, 2.9, 4.3, 1.3, 'versicolor'],
#        [5.8, 2.7, 4.1, 1.0, 'versicolor'],
#        [6.0, 3.4, 4.5, 1.6, 'versicolor'],
#        [5.8, 2.7, 3.9, 1.2, 'versicolor'],
#        [5.5, 2.6, 4.4, 1.2, 'versicolor'],
#        [5.8, 2.8, 5.1, 2.4, 'virginica'],
#        [5.6, 3.0, 4.1, 1.3, 'versicolor'],
#        [6.1, 3.0, 4.9, 1.8, 'virginica'],
#        [5.0, 2.0, 3.5, 1.0, 'versicolor'],
#        [6.7, 3.1, 4.7, 1.5, 'versicolor'],
#        [5.0, 2.3, 3.3, 1.0, 'versicolor'],
#        [5.7, 2.9, 4.2, 1.3, 'versicolor'],
#        [7.2, 3.2, 6.0, 1.8, 'virginica'],
#        [6.2, 2.8, 4.8, 1.8, 'virginica'],
#        [6.1, 2.9, 4.7, 1.4, 'versicolor'],
#        [7.2, 3.0, 5.8, 1.6, 'virginica'],
#        [6.6, 3.0, 4.4, 1.4, 'versicolor'],
#        [7.6, 3.0, 6.6, 2.1, 'virginica'],
#        [7.7, 3.0, 6.1, 2.3, 'virginica'],
#        [5.5, 2.4, 3.8, 1.1, 'versicolor'],
#        [6.3, 2.5, 4.9, 1.5, 'versicolor'],
#        [6.7, 3.0, 5.2, 2.3, 'virginica'],
#        [6.5, 3.0, 5.8, 2.2, 'virginica'],
#        [7.0, 3.2, 4.7, 1.4, 'versicolor'],
#        [6.4, 3.2, 4.5, 1.5, 'versicolor'],
#        [6.3, 2.5, 5.0, 1.9, 'virginica'],
#        [7.1, 3.0, 5.9, 2.1, 'virginica'],
#        [5.7, 2.8, 4.1, 1.3, 'versicolor'],
#        [6.7, 3.3, 5.7, 2.5, 'virginica'],
#        [5.5, 2.3, 4.0, 1.3, 'versicolor'],
#        [5.6, 2.8, 4.9, 2.0, 'virginica'],
#        [6.5, 3.2, 5.1, 2.0, 'virginica'],
#        [6.8, 2.8, 4.8, 1.4, 'versicolor'],
#        [5.5, 2.4, 3.7, 1.0, 'versicolor'],
#        [6.7, 3.1, 4.4, 1.4, 'versicolor'],
#        [5.9, 3.0, 4.2, 1.5, 'versicolor'],
#        [6.7, 2.5, 5.8, 1.8, 'virginica'],
#        [6.7, 3.0, 5.0, 1.7, 'versicolor'],
#        [5.7, 2.8, 4.5, 1.3, 'versicolor'],
#        [7.7, 3.8, 6.7, 2.2, 'virginica'],
#        [5.8, 2.7, 5.1, 1.9, 'virginica'],
#        [5.6, 2.9, 3.6, 1.3, 'versicolor'],
#        [6.3, 3.3, 6.0, 2.5, 'virginica'],
#        [5.7, 2.5, 5.0, 2.0, 'virginica'],
#        [4.9, 2.5, 4.5, 1.7, 'virginica'],
#        [6.2, 2.9, 4.3, 1.3, 'versicolor'],
#        [7.9, 3.8, 6.4, 2.0, 'virginica'],
#        [7.2, 3.6, 6.1, 2.5, 'virginica'],
#        [6.9, 3.2, 5.7, 2.3, 'virginica'],
#        [5.7, 2.6, 3.5, 1.0, 'versicolor'],
#        [6.9, 3.1, 5.4, 2.1, 'virginica'],
#        [6.0, 2.2, 4.0, 1.0, 'versicolor'],
#        [5.9, 3.0, 5.1, 1.8, 'virginica'],
#        [6.3, 3.3, 4.7, 1.6, 'versicolor'],
#        [6.4, 2.8, 5.6, 2.1, 'virginica'],
#        [5.7, 3.0, 4.2, 1.2, 'versicolor'],
#        [6.1, 3.0, 4.6, 1.4, 'versicolor'],
#        [6.4, 2.7, 5.3, 1.9, 'virginica'],
#        [5.5, 2.5, 4.0, 1.3, 'versicolor'],
#        [6.3, 2.3, 4.4, 1.3, 'versicolor'],
#        [6.9, 3.1, 5.1, 2.3, 'virginica'],
#        [6.4, 3.2, 5.3, 2.3, 'virginica'],
#        [5.8, 2.6, 4.0, 1.2, 'versicolor'],
#        [6.2, 2.2, 4.5, 1.5, 'versicolor'],
#        [6.0, 2.7, 5.1, 1.6, 'versicolor']], dtype=object), 'info_gain': 0.3360426200396147}
# {'feature_index': 3, 'threshold': 1.7, 'dataset_left': array([[6.0, 2.9, 4.5, 1.5, 'versicolor'],
#        [5.1, 2.5, 3.0, 1.1, 'versicolor'],
#        [5.6, 2.7, 4.2, 1.3, 'versicolor'],
#        [6.0, 2.2, 5.0, 1.5, 'virginica'],
#        [5.4, 3.0, 4.5, 1.5, 'versicolor'],
#        [6.4, 2.9, 4.3, 1.3, 'versicolor'],
#        [5.8, 2.7, 4.1, 1.0, 'versicolor'],
#        [6.0, 3.4, 4.5, 1.6, 'versicolor'],
#        [5.8, 2.7, 3.9, 1.2, 'versicolor'],
#        [5.5, 2.6, 4.4, 1.2, 'versicolor'],
#        [5.6, 3.0, 4.1, 1.3, 'versicolor'],
#        [5.0, 2.0, 3.5, 1.0, 'versicolor'],
#        [6.7, 3.1, 4.7, 1.5, 'versicolor'],
#        [5.0, 2.3, 3.3, 1.0, 'versicolor'],
#        [5.7, 2.9, 4.2, 1.3, 'versicolor'],
#        [6.1, 2.9, 4.7, 1.4, 'versicolor'],
#        [7.2, 3.0, 5.8, 1.6, 'virginica'],
#        [6.6, 3.0, 4.4, 1.4, 'versicolor'],
#        [5.5, 2.4, 3.8, 1.1, 'versicolor'],
#        [6.3, 2.5, 4.9, 1.5, 'versicolor'],
#        [7.0, 3.2, 4.7, 1.4, 'versicolor'],
#        [6.4, 3.2, 4.5, 1.5, 'versicolor'],
#        [5.7, 2.8, 4.1, 1.3, 'versicolor'],
#        [5.5, 2.3, 4.0, 1.3, 'versicolor'],
#        [6.8, 2.8, 4.8, 1.4, 'versicolor'],
#        [5.5, 2.4, 3.7, 1.0, 'versicolor'],
#        [6.7, 3.1, 4.4, 1.4, 'versicolor'],
#        [5.9, 3.0, 4.2, 1.5, 'versicolor'],
#        [6.7, 3.0, 5.0, 1.7, 'versicolor'],
#        [5.7, 2.8, 4.5, 1.3, 'versicolor'],
#        [5.6, 2.9, 3.6, 1.3, 'versicolor'],
#        [4.9, 2.5, 4.5, 1.7, 'virginica'],
#        [6.2, 2.9, 4.3, 1.3, 'versicolor'],
#        [5.7, 2.6, 3.5, 1.0, 'versicolor'],
#        [6.0, 2.2, 4.0, 1.0, 'versicolor'],
#        [6.3, 3.3, 4.7, 1.6, 'versicolor'],
#        [5.7, 3.0, 4.2, 1.2, 'versicolor'],
#        [6.1, 3.0, 4.6, 1.4, 'versicolor'],
#        [5.5, 2.5, 4.0, 1.3, 'versicolor'],
#        [6.3, 2.3, 4.4, 1.3, 'versicolor'],
#        [5.8, 2.6, 4.0, 1.2, 'versicolor'],
#        [6.2, 2.2, 4.5, 1.5, 'versicolor'],
#        [6.0, 2.7, 5.1, 1.6, 'versicolor']], dtype=object), 'dataset_right': array([[6.7, 3.3, 5.7, 2.1, 'virginica'],
#        [6.8, 3.2, 5.9, 2.3, 'virginica'],
#        [5.8, 2.7, 5.1, 1.9, 'virginica'],
#        [6.4, 2.8, 5.6, 2.2, 'virginica'],
#        [6.5, 3.0, 5.2, 2.0, 'virginica'],
#        [6.4, 3.1, 5.5, 1.8, 'virginica'],
#        [7.3, 2.9, 6.3, 1.8, 'virginica'],
#        [7.7, 2.8, 6.7, 2.0, 'virginica'],
#        [6.2, 3.4, 5.4, 2.3, 'virginica'],
#        [7.7, 2.6, 6.9, 2.3, 'virginica'],
#        [5.8, 2.8, 5.1, 2.4, 'virginica'],
#        [6.1, 3.0, 4.9, 1.8, 'virginica'],
#        [7.2, 3.2, 6.0, 1.8, 'virginica'],
#        [6.2, 2.8, 4.8, 1.8, 'virginica'],
#        [7.6, 3.0, 6.6, 2.1, 'virginica'],
#        [7.7, 3.0, 6.1, 2.3, 'virginica'],
#        [6.7, 3.0, 5.2, 2.3, 'virginica'],
#        [6.5, 3.0, 5.8, 2.2, 'virginica'],
#        [6.3, 2.5, 5.0, 1.9, 'virginica'],
#        [7.1, 3.0, 5.9, 2.1, 'virginica'],
#        [6.7, 3.3, 5.7, 2.5, 'virginica'],
#        [5.6, 2.8, 4.9, 2.0, 'virginica'],
#        [6.5, 3.2, 5.1, 2.0, 'virginica'],
#        [6.7, 2.5, 5.8, 1.8, 'virginica'],
#        [7.7, 3.8, 6.7, 2.2, 'virginica'],
#        [5.8, 2.7, 5.1, 1.9, 'virginica'],
#        [6.3, 3.3, 6.0, 2.5, 'virginica'],
#        [5.7, 2.5, 5.0, 2.0, 'virginica'],
#        [7.9, 3.8, 6.4, 2.0, 'virginica'],
#        [7.2, 3.6, 6.1, 2.5, 'virginica'],
#        [6.9, 3.2, 5.7, 2.3, 'virginica'],
#        [6.9, 3.1, 5.4, 2.1, 'virginica'],
#        [5.9, 3.0, 5.1, 1.8, 'virginica'],
#        [6.4, 2.8, 5.6, 2.1, 'virginica'],
#        [6.4, 2.7, 5.3, 1.9, 'virginica'],
#        [6.9, 3.1, 5.1, 2.3, 'virginica'],
#        [6.4, 3.2, 5.3, 2.3, 'virginica']], dtype=object), 'info_gain': 0.43023255813953487}
# {'feature_index': 0, 'threshold': 4.9, 'dataset_left': array([[4.9, 2.5, 4.5, 1.7, 'virginica']], dtype=object), 'dataset_right': array([[6.0, 2.9, 4.5, 1.5, 'versicolor'],
#        [5.1, 2.5, 3.0, 1.1, 'versicolor'],
#        [5.6, 2.7, 4.2, 1.3, 'versicolor'],
#        [6.0, 2.2, 5.0, 1.5, 'virginica'],
#        [5.4, 3.0, 4.5, 1.5, 'versicolor'],
#        [6.4, 2.9, 4.3, 1.3, 'versicolor'],
#        [5.8, 2.7, 4.1, 1.0, 'versicolor'],
#        [6.0, 3.4, 4.5, 1.6, 'versicolor'],
#        [5.8, 2.7, 3.9, 1.2, 'versicolor'],
#        [5.5, 2.6, 4.4, 1.2, 'versicolor'],
#        [5.6, 3.0, 4.1, 1.3, 'versicolor'],
#        [5.0, 2.0, 3.5, 1.0, 'versicolor'],
#        [6.7, 3.1, 4.7, 1.5, 'versicolor'],
#        [5.0, 2.3, 3.3, 1.0, 'versicolor'],
#        [5.7, 2.9, 4.2, 1.3, 'versicolor'],
#        [6.1, 2.9, 4.7, 1.4, 'versicolor'],
#        [7.2, 3.0, 5.8, 1.6, 'virginica'],
#        [6.6, 3.0, 4.4, 1.4, 'versicolor'],
#        [5.5, 2.4, 3.8, 1.1, 'versicolor'],
#        [6.3, 2.5, 4.9, 1.5, 'versicolor'],
#        [7.0, 3.2, 4.7, 1.4, 'versicolor'],
#        [6.4, 3.2, 4.5, 1.5, 'versicolor'],
#        [5.7, 2.8, 4.1, 1.3, 'versicolor'],
#        [5.5, 2.3, 4.0, 1.3, 'versicolor'],
#        [6.8, 2.8, 4.8, 1.4, 'versicolor'],
#        [5.5, 2.4, 3.7, 1.0, 'versicolor'],
#        [6.7, 3.1, 4.4, 1.4, 'versicolor'],
#        [5.9, 3.0, 4.2, 1.5, 'versicolor'],
#        [6.7, 3.0, 5.0, 1.7, 'versicolor'],
#        [5.7, 2.8, 4.5, 1.3, 'versicolor'],
#        [5.6, 2.9, 3.6, 1.3, 'versicolor'],
#        [6.2, 2.9, 4.3, 1.3, 'versicolor'],
#        [5.7, 2.6, 3.5, 1.0, 'versicolor'],
#        [6.0, 2.2, 4.0, 1.0, 'versicolor'],
#        [6.3, 3.3, 4.7, 1.6, 'versicolor'],
#        [5.7, 3.0, 4.2, 1.2, 'versicolor'],
#        [6.1, 3.0, 4.6, 1.4, 'versicolor'],
#        [5.5, 2.5, 4.0, 1.3, 'versicolor'],
#        [6.3, 2.3, 4.4, 1.3, 'versicolor'],
#        [5.8, 2.6, 4.0, 1.2, 'versicolor'],
#        [6.2, 2.2, 4.5, 1.5, 'versicolor'],
#        [6.0, 2.7, 5.1, 1.6, 'versicolor']], dtype=object), 'info_gain': 0.04120631486775354}
# {'feature_index': 0, 'threshold': 7.0, 'dataset_left': array([[6.0, 2.9, 4.5, 1.5, 'versicolor'],
#        [5.1, 2.5, 3.0, 1.1, 'versicolor'],
#        [5.6, 2.7, 4.2, 1.3, 'versicolor'],
#        [6.0, 2.2, 5.0, 1.5, 'virginica'],
#        [5.4, 3.0, 4.5, 1.5, 'versicolor'],
#        [6.4, 2.9, 4.3, 1.3, 'versicolor'],
#        [5.8, 2.7, 4.1, 1.0, 'versicolor'],
#        [6.0, 3.4, 4.5, 1.6, 'versicolor'],
#        [5.8, 2.7, 3.9, 1.2, 'versicolor'],
#        [5.5, 2.6, 4.4, 1.2, 'versicolor'],
#        [5.6, 3.0, 4.1, 1.3, 'versicolor'],
#        [5.0, 2.0, 3.5, 1.0, 'versicolor'],
#        [6.7, 3.1, 4.7, 1.5, 'versicolor'],
#        [5.0, 2.3, 3.3, 1.0, 'versicolor'],
#        [5.7, 2.9, 4.2, 1.3, 'versicolor'],
#        [6.1, 2.9, 4.7, 1.4, 'versicolor'],
#        [6.6, 3.0, 4.4, 1.4, 'versicolor'],
#        [5.5, 2.4, 3.8, 1.1, 'versicolor'],
#        [6.3, 2.5, 4.9, 1.5, 'versicolor'],
#        [7.0, 3.2, 4.7, 1.4, 'versicolor'],
#        [6.4, 3.2, 4.5, 1.5, 'versicolor'],
#        [5.7, 2.8, 4.1, 1.3, 'versicolor'],
#        [5.5, 2.3, 4.0, 1.3, 'versicolor'],
#        [6.8, 2.8, 4.8, 1.4, 'versicolor'],
#        [5.5, 2.4, 3.7, 1.0, 'versicolor'],
#        [6.7, 3.1, 4.4, 1.4, 'versicolor'],
#        [5.9, 3.0, 4.2, 1.5, 'versicolor'],
#        [6.7, 3.0, 5.0, 1.7, 'versicolor'],
#        [5.7, 2.8, 4.5, 1.3, 'versicolor'],
#        [5.6, 2.9, 3.6, 1.3, 'versicolor'],
#        [6.2, 2.9, 4.3, 1.3, 'versicolor'],
#        [5.7, 2.6, 3.5, 1.0, 'versicolor'],
#        [6.0, 2.2, 4.0, 1.0, 'versicolor'],
#        [6.3, 3.3, 4.7, 1.6, 'versicolor'],
#        [5.7, 3.0, 4.2, 1.2, 'versicolor'],
#        [6.1, 3.0, 4.6, 1.4, 'versicolor'],
#        [5.5, 2.5, 4.0, 1.3, 'versicolor'],
#        [6.3, 2.3, 4.4, 1.3, 'versicolor'],
#        [5.8, 2.6, 4.0, 1.2, 'versicolor'],
#        [6.2, 2.2, 4.5, 1.5, 'versicolor'],
#        [6.0, 2.7, 5.1, 1.6, 'versicolor']], dtype=object), 'dataset_right': array([[7.2, 3.0, 5.8, 1.6, 'virginica']], dtype=object), 'info_gain': 0.0442453404125877}
# X_2 <= 1.9 ? 0.3360426200396147
#  left:setosa
#  right:X_3 <= 1.7 ? 0.43023255813953487
#   left:X_0 <= 4.9 ? 0.04120631486775354
#     left:virginica
#     right:X_0 <= 7.0 ? 0.0442453404125877
#         left:versicolor
#         right:virginica
#   right:virginica

# %%
Y_pred = classifier.predict(X_test) 
from sklearn.metrics import accuracy_score
accuracy_score(Y_test, Y_pred)
